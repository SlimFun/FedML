# %%
import sys, os
import argparse

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "./../../../../")))
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "./../../../")))

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "")))

# %%
from fedml_api.data_preprocessing.cifar10.data_loader import load_partition_data_cifar10
from fedml_api.standalone.fedavg.my_model_trainer_classification import MyModelTrainer as MyModelTrainerCLS
from fedml_api.model.contrastive_cv.resnet_with_embedding import Resnet56
from CovaMNet2 import CovaMResnet56

import torch
from torch import nn
from collections import OrderedDict
import torch.nn.functional as F

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import numpy as np
import random
import pickle
import wandb

from pcgrad import PCGrad

# from triplet_loss import TripletLoss
from hard_triplet_loss import TripletLoss
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: greenlet.greenlet size changed, may indicate binary incompatibility. Expected 144 from C header, got 152 from PyObject
# <frozen importlib._bootstrap>:219: RuntimeWarning: greenlet.greenlet size changed, may indicate binary incompatibility. Expected 144 from C header, got 152 from PyObject
# <frozen importlib._bootstrap>:219: RuntimeWarning: greenlet.greenlet size changed, may indicate binary incompatibility. Expected 144 from C header, got 152 from PyObject
# <frozen importlib._bootstrap>:219: RuntimeWarning: greenlet.greenlet size changed, may indicate binary incompatibility. Expected 144 from C header, got 152 from PyObject

# %%
dataset = 'cifar10'
data_dir = "./../../../data/cifar10"
partition_method = 'hetero'
# partition_method = 'homo'
partition_alpha = 0.5
client_num_in_total = 10
batch_size = 100
total_epochs = 500

save_model_path = 'model/cs_{0}_{1}_client_{2}_variable_covaM_epochs_{3}.pt'

device = 'cuda:1'
with_cova = True

wandb.init(
            # project="federated_nas",
            project="cova",
            name="Cova_" + str(partition_method) + "_clients" + str(client_num_in_total) + "_pcgrad_wn_2:1_adam-leaky_relu_without_mean_with_cova" + str(
                with_cova)
        )
# config = wandb.config
# config.learning_rate = 0.01

with open(f'dataset_{partition_method}_{client_num_in_total}.pickle', 'rb') as f:
    dataset = pickle.load(f)
# [train_data_num, test_data_num, train_data_global, test_data_global, \
# #             train_data_local_num_dict, train_data_local_dict, test_data_local_dict, \
# #             class_num]
# Out:
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: slimfun (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.11.2<br/>
#                 Syncing run <strong style="color:#cdcd00">Cova_hetero_clients10_pcgrad_wn_adam-leaky_relu_without_mean_with_covaTrue</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/slimfun/cova" target="_blank">https://wandb.ai/slimfun/cova</a><br/>
#                 Run page: <a href="https://wandb.ai/slimfun/cova/runs/gt5jyhsj" target="_blank">https://wandb.ai/slimfun/cova/runs/gt5jyhsj</a><br/>
#                 Run data is saved locally in <code>/home/fw1/nfs_mnt/FedML/fedml_experiments/distributed/contrastive_fed/wandb/run-20211112_131259-gt5jyhsj</code><br/><br/>

# %%
# from collections import Counter
# ls = np.array([int(l) for l in labels])
# counter_result = Counter(ls)
# print(Counter(ls))
# print(dataset[5])

# %%
# model = Resnet56(class_num=dataset[-1], neck='bnneck')
# model.load_state_dict(torch.load('model/cs_3_homo_client_0_oral_epochs_200.pt'))

# %%
with open(f'data_dict.pickle', 'rb') as f:
    data_dict = pickle.load(f)

# %%
cl = []
for k, v in data_dict.items():
#     print(len(v))
    cl.append(torch.stack(v).to(device))
# print(cl[0].shape)
print(len(cl))
# Out:
# 10

# %%
# def cal_covariance(input):

# #     CovaMatrix_list = []
# #     mean_list = []
#     B, C, h, w = input.size()
# #     print(B)
#     support_set_sam = input.permute(1, 0, 2, 3)
#     support_set_sam = support_set_sam.contiguous().view(C, -1)
    
#     mean_support = torch.mean(support_set_sam, 1, True)
# #     mean_list.append(mean_support)
    
#     support_set_sam = support_set_sam-mean_support
    
#     covariance_matrix = support_set_sam@torch.transpose(support_set_sam, 0, 1)
#     covariance_matrix = torch.div(covariance_matrix, h*w*B-1)
    
#     return covariance_matrix.clone().detach(), mean_support.clone().detach()


# def get_cova(model, device):
#     cova_list = [0 for i in range(10)]
#     mean_list = [0 for i in range(10)]
    
#     model.to(device)
#     model.eval()
    
#     features = []
    
#     with torch.no_grad():
#         for k, v in data_dict.items():
#             x = torch.stack(data_dict[k]).to(device)
# #             print(x.shape)
#             score, feats = model(x)
#             covariance_matrix, mean_support = cal_covariance(feats.to(device))
#             cova_list[k] = covariance_matrix.to(device)
#             mean_list[k] = mean_support.to(device)
            
#     return cova_list, mean_list

# %%
class Client(object):
    def __init__(self, client_index, train_data_local_dict, train_data_local_num_dict, test_data_local_dict, device, model):
        self.id = client_index
        self.train_data = train_data_local_dict[self.id]
        self.local_sample_number = train_data_local_num_dict[self.id]
        self.test_local = test_data_local_dict[self.id]
        
        self.device = device
        self.model = model
model1 = CovaMResnet56(class_num=dataset[-1], neck='bnneck', with_cova=with_cova)
client_1 = Client(0, dataset[5], dataset[4], dataset[6], device, model1)

# %%
def test(model, test_data, device, cl, ml):
#     cl = cms[0]
#     ml = cms[1]
    
    model.to(device)
    model.eval()

    metrics = {
        'test_correct': 0,
        'test_loss': 0,
        'test_total': 0,
        'correct_cova': 0
    }

    criterion = nn.CrossEntropyLoss().to(device)

    with torch.no_grad():
        for batch_idx, (x, target) in enumerate(test_data):
            x = x.to(device)
            target = target.to(device)
#             support_ml = []
#             for l in target:
#                 support_ml.append(ml[l.data].to(device))
            pred, pred_ce_cova, feat = model(x, cl, ml=None)
            loss = criterion(pred, target)
            
#             loss_ce_cova = criterion(pred_ce_cova, target)

            _, predicted = torch.max(pred, -1)
            _, predicted_ce_cova = torch.max(pred_ce_cova, -1)
            correct = predicted.eq(target).sum()
            correct_ce_cova = predicted_ce_cova.eq(target).sum()

            metrics['test_correct'] += correct.item()
#             metrics['test_correct'] += correct_ce_cova.item()
            metrics['test_loss'] += loss.item() * target.size(0)
            metrics['test_total'] += target.size(0)
            metrics['correct_cova'] += correct_ce_cova.item()
            
    return metrics

def train_model(client, epochs):
#     learning_rate = 0.001
#     wd = 0.0001
#     learning_rate = 0.00035
#     wd = 0.0005

#     cl = cms[0]
#     ml = cms[1]
    
    
    margin = 0.3
    
    client.model.to(client.device)
    client.model.train()
    
    criterion = nn.CrossEntropyLoss().to(device)
    criterion2 = nn.CrossEntropyLoss().to(device)
    mse_loss = nn.MSELoss().to(device)
    
#     curr_lr = learning_rate
#     optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad, client.model.parameters()), lr=curr_lr,
#                                          weight_decay=wd, amsgrad=True)
#     optimizer = torch.optim.SGD(client.model.parameters(), lr=0.001,
#                       momentum=0.9, weight_decay=5e-4)
    optimizer = PCGrad(torch.optim.Adam(client.model.parameters(), lr=0.001, betas=(0.5, 0.9)))
#     scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)

    epoch_loss = []
    total_step = len(client.train_data)
#     wandb.watch(client.model, log='all')
    lbd = 0.1
    for epoch in range(epochs):
        
#         if epoch > 0:
        
#         print(ml[0])
        
        client.model.train()
        batch_loss = []
        for batch_idx, (x, labels) in enumerate(client.train_data):
            
#             cl, ml = get_cova(client.model, client.device)
#             if epoch > 0:
#                 print(cl[0])
            x, labels = x.to(device), labels.to(device)
#             print(labels.shape)
            client.model.zero_grad()
#             support_ml = []
#             for l in labels:
#                 # B, 256, 64
#                 support_ml.append(ml[l.data].to(device))
#             print(cl[0].shape)
            cls_score, cova_score, feat = client.model(x, support_imgs=cl, ml=None)
#             print(score.shape)
#             print(cova_score)
#             print(cova_score)
#             loss = criterion(cova_score, labels).to(device)
#             if epoch < 100:
#             loss = criterion(cls_score, labels)
            loss1 = 2*criterion(cls_score, labels)
            loss2 = criterion2(cova_score, labels)
            losses = [loss2, loss1]
#             if epoch > 100 :
#             loss = criterion(cova_score, labels).to(device)
#             loss = loss.to(device) + criterion(cova_score, labels).to(device)
            lbd += (1-0.1) / (epochs-100)
#             loss.backward()
            optimizer.pc_backward(losses)
        
#             torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

            optimizer.step()
            batch_loss.append((loss1+loss2).item())
        
#         print(cl[0])
            
#         if epoch % 50 == 0:
#             torch.save(client.model.state_dict(), str.format(save_model_path, client_num_in_total, partition_method, client.id, epoch))
        epoch_loss.append(sum(batch_loss) / len(batch_loss))
#         scheduler.step()
        print('Client Index = {}\tEpoch: {}\tLoss: {:.6f}'.format(
            client.id, epoch, sum(batch_loss) / len(batch_loss)))
        
        metrics = test(client.model, client.test_local, client.device, cl, None)
        test_correct = metrics['test_correct']/metrics['test_total']
        test_loss = metrics['test_loss']/metrics['test_total']
        correct_ce_cova = metrics['correct_cova']/metrics['test_total']
#         print(metrics['test_total'])
        print(f'test_correct: {test_correct}; test_loss: {test_loss}')
        wandb.log({
#             'epoch' : epoch,
            'train_loss': sum(batch_loss) / len(batch_loss),
            'test_correct' : test_correct,
            'test_loss' : test_loss,
            'correct_cova' : correct_ce_cova
        }, step=epoch)
        
    torch.save(client.model.state_dict(), str.format(save_model_path, client_num_in_total, partition_method, client.id, epochs))

# %%
train_model(client_1, 200)
# Out:
# Client Index = 0	Epoch: 0	Loss: 11.137683
# test_correct: 0.2272; test_loss: 2.353565745353699
# Client Index = 0	Epoch: 1	Loss: 4.800422
# test_correct: 0.2604; test_loss: 2.3155314898490906
# Client Index = 0	Epoch: 2	Loss: 3.690836
# test_correct: 0.2649; test_loss: 2.5568864011764525
# Client Index = 0	Epoch: 3	Loss: 3.360426
# test_correct: 0.2518; test_loss: 2.402839887142181
# Client Index = 0	Epoch: 4	Loss: 3.103593
# test_correct: 0.3203; test_loss: 2.2190500390529633
# Client Index = 0	Epoch: 5	Loss: 2.933457
# test_correct: 0.2962; test_loss: 2.3089129543304443
# Client Index = 0	Epoch: 6	Loss: 2.803888
# test_correct: 0.2841; test_loss: 2.3291733253002165
# Client Index = 0	Epoch: 7	Loss: 2.685532
# test_correct: 0.2963; test_loss: 2.3354899859428406
# Client Index = 0	Epoch: 8	Loss: 2.572863
# test_correct: 0.343; test_loss: 2.249459025859833
# Client Index = 0	Epoch: 9	Loss: 2.500924
# test_correct: 0.3576; test_loss: 2.0536477851867674
# Client Index = 0	Epoch: 10	Loss: 2.430941
# test_correct: 0.3519; test_loss: 2.195952626466751
# Client Index = 0	Epoch: 11	Loss: 2.388587
# test_correct: 0.367; test_loss: 2.110582150220871
# Client Index = 0	Epoch: 12	Loss: 2.284044
# test_correct: 0.3587; test_loss: 2.2106551218032835
# Client Index = 0	Epoch: 13	Loss: 2.239061
# test_correct: 0.3466; test_loss: 2.343842632770538
# Client Index = 0	Epoch: 14	Loss: 2.178339
# test_correct: 0.3656; test_loss: 2.1546388173103335
# test_correct: 0.369; test_loss: 2.10177870631218
# Client Index = 0	Epoch: 18	Loss: 1.999070
# test_correct: 0.4126; test_loss: 2.1073428666591645
# Client Index = 0	Epoch: 19	Loss: 1.937779
# test_correct: 0.4376; test_loss: 1.9368135964870452
# Client Index = 0	Epoch: 20	Loss: 1.918242
# test_correct: 0.4081; test_loss: 2.0684889483451845
# Client Index = 0	Epoch: 21	Loss: 1.887174
# test_correct: 0.3973; test_loss: 2.180802904367447
# Client Index = 0	Epoch: 22	Loss: 1.820253
# test_correct: 0.3577; test_loss: 2.651247067451477
# Client Index = 0	Epoch: 23	Loss: 1.806906
# test_correct: 0.4451; test_loss: 1.9155762255191804
# Client Index = 0	Epoch: 24	Loss: 1.774543
# test_correct: 0.4669; test_loss: 1.958211851119995
# Client Index = 0	Epoch: 25	Loss: 1.747840
# test_correct: 0.432; test_loss: 1.9945743918418883
# Client Index = 0	Epoch: 26	Loss: 1.689188
# test_correct: 0.4039; test_loss: 2.268875399827957
# Client Index = 0	Epoch: 27	Loss: 1.691280
# test_correct: 0.3984; test_loss: 2.360945942401886
# Client Index = 0	Epoch: 28	Loss: 1.655526
# test_correct: 0.45; test_loss: 1.951643785238266
# Client Index = 0	Epoch: 29	Loss: 1.625459
# test_correct: 0.4031; test_loss: 2.0351993191242217
# Client Index = 0	Epoch: 30	Loss: 1.640996
# test_correct: 0.379; test_loss: 2.6144936621189117
# Client Index = 0	Epoch: 31	Loss: 1.608474
# test_correct: 0.4327; test_loss: 2.1805771923065187
# Client Index = 0	Epoch: 32	Loss: 1.539415
# test_correct: 0.4607; test_loss: 1.9992488849163055
# Client Index = 0	Epoch: 33	Loss: 1.526567
# test_correct: 0.4496; test_loss: 2.1735233891010286
# Client Index = 0	Epoch: 34	Loss: 1.529409
# test_correct: 0.4039; test_loss: 2.693093485832214
# Client Index = 0	Epoch: 35	Loss: 1.487095
# test_correct: 0.4739; test_loss: 1.8974478137493134
# Client Index = 0	Epoch: 36	Loss: 1.460631
# test_correct: 0.4315; test_loss: 2.138822444677353
# Client Index = 0	Epoch: 37	Loss: 1.454145
# test_correct: 0.4444; test_loss: 2.6278182089328768
# Client Index = 0	Epoch: 38	Loss: 1.440435
# test_correct: 0.4833; test_loss: 1.9347847664356232
# Client Index = 0	Epoch: 39	Loss: 1.420199
# test_correct: 0.4719; test_loss: 2.042357335090637
# Client Index = 0	Epoch: 40	Loss: 1.385426
# test_correct: 0.4759; test_loss: 1.9016028821468354
# Client Index = 0	Epoch: 41	Loss: 1.391930
# test_correct: 0.4698; test_loss: 2.3642344760894773
# Client Index = 0	Epoch: 42	Loss: 1.368437
# test_correct: 0.4645; test_loss: 2.4507714784145356
# Client Index = 0	Epoch: 43	Loss: 1.341987
# test_correct: 0.4752; test_loss: 2.0199588096141814
# Client Index = 0	Epoch: 44	Loss: 1.355511
# test_correct: 0.4404; test_loss: 2.219044259786606
# Client Index = 0	Epoch: 45	Loss: 1.276677
# test_correct: 0.4763; test_loss: 2.391413489580154
# Client Index = 0	Epoch: 46	Loss: 1.314454
# test_correct: 0.4948; test_loss: 1.978865921497345
# Client Index = 0	Epoch: 47	Loss: 1.277568
# test_correct: 0.4901; test_loss: 1.9705768465995788
# Client Index = 0	Epoch: 48	Loss: 1.252124
# test_correct: 0.4489; test_loss: 2.598931589126587
# Client Index = 0	Epoch: 49	Loss: 1.257244
# test_correct: 0.4937; test_loss: 2.209203487634659
# Client Index = 0	Epoch: 50	Loss: 1.241767
# test_correct: 0.4729; test_loss: 2.2025968432426453
# Client Index = 0	Epoch: 51	Loss: 1.198184
# test_correct: 0.4706; test_loss: 2.4188950181007387
# Client Index = 0	Epoch: 52	Loss: 1.206002
# test_correct: 0.4707; test_loss: 2.609060662984848
# Client Index = 0	Epoch: 53	Loss: 1.189415
# test_correct: 0.5101; test_loss: 2.266902496814728
# Client Index = 0	Epoch: 54	Loss: 1.168716
# test_correct: 0.4955; test_loss: 2.4956945168972013
# Client Index = 0	Epoch: 55	Loss: 1.147335
# test_correct: 0.4373; test_loss: 2.4992548596858977
# Client Index = 0	Epoch: 56	Loss: 1.152183
# test_correct: 0.4322; test_loss: 2.4431427049636842
# Client Index = 0	Epoch: 57	Loss: 1.133305
# test_correct: 0.5034; test_loss: 2.309243782758713
# Client Index = 0	Epoch: 58	Loss: 1.129648
# test_correct: 0.482; test_loss: 2.541844251155853
# Client Index = 0	Epoch: 59	Loss: 1.122432
# test_correct: 0.4929; test_loss: 2.140366312265396
# Client Index = 0	Epoch: 60	Loss: 1.113462
# test_correct: 0.4799; test_loss: 2.495999504327774
# Client Index = 0	Epoch: 61	Loss: 1.067777
# test_correct: 0.4968; test_loss: 2.348124022483826
# Client Index = 0	Epoch: 62	Loss: 1.067325
# test_correct: 0.4545; test_loss: 2.425788937807083
# Client Index = 0	Epoch: 63	Loss: 1.084680
# test_correct: 0.5191; test_loss: 2.2895126140117643
# Client Index = 0	Epoch: 64	Loss: 1.051103
# test_correct: 0.4786; test_loss: 2.4306219351291656
# Client Index = 0	Epoch: 65	Loss: 1.022288
# test_correct: 0.4941; test_loss: 2.464534478187561
# Client Index = 0	Epoch: 66	Loss: 1.037625
# test_correct: 0.503; test_loss: 2.2068117797374724
# Client Index = 0	Epoch: 67	Loss: 1.023800
# test_correct: 0.474; test_loss: 2.4571142518520355
# Client Index = 0	Epoch: 68	Loss: 1.036886
# test_correct: 0.513; test_loss: 2.153317701816559
# Client Index = 0	Epoch: 69	Loss: 1.059894
# test_correct: 0.506; test_loss: 2.1601267504692077
# Client Index = 0	Epoch: 70	Loss: 1.003534
# test_correct: 0.5136; test_loss: 2.277911010980606
# Client Index = 0	Epoch: 71	Loss: 0.959755
# test_correct: 0.4854; test_loss: 2.2699947822093964
# Client Index = 0	Epoch: 72	Loss: 0.984286
# test_correct: 0.4829; test_loss: 2.321006505489349
# Client Index = 0	Epoch: 73	Loss: 0.975533
# test_correct: 0.5181; test_loss: 2.1472360634803773
# Client Index = 0	Epoch: 74	Loss: 0.984949
# test_correct: 0.4889; test_loss: 2.240973335504532
# Client Index = 0	Epoch: 75	Loss: 0.926669
# test_correct: 0.5118; test_loss: 2.3042163944244383
# Client Index = 0	Epoch: 76	Loss: 0.931502
# test_correct: 0.5089; test_loss: 2.284504572153091
# Client Index = 0	Epoch: 77	Loss: 0.900060
# test_correct: 0.5106; test_loss: 2.384232975244522
# Client Index = 0	Epoch: 78	Loss: 0.915734
# test_correct: 0.5099; test_loss: 2.400327194929123
# Client Index = 0	Epoch: 79	Loss: 0.909658
# test_correct: 0.5274; test_loss: 1.958473355770111
# Client Index = 0	Epoch: 80	Loss: 0.893197
# test_correct: 0.5233; test_loss: 2.030731134414673
# Client Index = 0	Epoch: 81	Loss: 0.928784
# test_correct: 0.5133; test_loss: 2.201999579668045
# Client Index = 0	Epoch: 82	Loss: 0.901683
# test_correct: 0.4922; test_loss: 2.3096608328819275
# Client Index = 0	Epoch: 83	Loss: 0.874926
# test_correct: 0.4854; test_loss: 2.572865815162659
# Client Index = 0	Epoch: 84	Loss: 0.891511
# test_correct: 0.4797; test_loss: 2.3498909676074984
# Client Index = 0	Epoch: 85	Loss: 0.857966
# test_correct: 0.4952; test_loss: 2.9552504873275756
# Client Index = 0	Epoch: 86	Loss: 0.843849
# test_correct: 0.4956; test_loss: 2.48739625453949
# Client Index = 0	Epoch: 87	Loss: 0.837544
# test_correct: 0.5106; test_loss: 2.244863603115082
# Client Index = 0	Epoch: 88	Loss: 0.854319
# test_correct: 0.5271; test_loss: 2.1984699785709383
# Client Index = 0	Epoch: 89	Loss: 0.835501
# Client Index = 0	Epoch: 90	Loss: 0.826111
# test_correct: 0.4927; test_loss: 2.3364459800720216
# Client Index = 0	Epoch: 91	Loss: 0.821631
# test_correct: 0.4731; test_loss: 2.554393233060837
# Client Index = 0	Epoch: 92	Loss: 0.787347
# test_correct: 0.492; test_loss: 2.3412318325042722
# Client Index = 0	Epoch: 93	Loss: 0.823598
# test_correct: 0.4464; test_loss: 2.6285488402843473
# Client Index = 0	Epoch: 94	Loss: 0.757152
# test_correct: 0.5183; test_loss: 2.2039555597305296
# Client Index = 0	Epoch: 95	Loss: 0.784633
# test_correct: 0.4842; test_loss: 2.3518189895153045
# Client Index = 0	Epoch: 96	Loss: 0.799762
# test_correct: 0.501; test_loss: 2.425767569541931
# Client Index = 0	Epoch: 97	Loss: 0.783692
# test_correct: 0.4874; test_loss: 3.061515552997589
# Client Index = 0	Epoch: 98	Loss: 0.769284
# test_correct: 0.4811; test_loss: 2.4321382105350495
# Client Index = 0	Epoch: 99	Loss: 0.756339
# test_correct: 0.4677; test_loss: 2.3673004698753357
# Client Index = 0	Epoch: 100	Loss: 0.754372
# test_correct: 0.53; test_loss: 2.377200800180435
# Client Index = 0	Epoch: 101	Loss: 0.739158
# test_correct: 0.5106; test_loss: 2.34568479180336
# Client Index = 0	Epoch: 102	Loss: 0.687351
# test_correct: 0.5133; test_loss: 2.3858979034423826
# Client Index = 0	Epoch: 103	Loss: 0.721847
# test_correct: 0.4724; test_loss: 2.5086353611946106
# Client Index = 0	Epoch: 104	Loss: 0.722518
# test_correct: 0.5082; test_loss: 2.366889383792877
# Client Index = 0	Epoch: 105	Loss: 0.715119
# test_correct: 0.475; test_loss: 2.685352178812027
# Client Index = 0	Epoch: 106	Loss: 0.702181
# test_correct: 0.4909; test_loss: 2.60749214887619
# Client Index = 0	Epoch: 107	Loss: 0.712771
# test_correct: 0.5079; test_loss: 2.1487072026729583
# Client Index = 0	Epoch: 108	Loss: 0.697096
# test_correct: 0.5137; test_loss: 2.4071463418006895
# Client Index = 0	Epoch: 109	Loss: 0.695111
# test_correct: 0.4659; test_loss: 2.7988789677619934
# Client Index = 0	Epoch: 110	Loss: 0.676098
# test_correct: 0.4996; test_loss: 2.5601007604598998
# Client Index = 0	Epoch: 111	Loss: 0.701960
# test_correct: 0.4938; test_loss: 2.5692099916934965
# Client Index = 0	Epoch: 112	Loss: 0.710300
# test_correct: 0.4933; test_loss: 2.635362218618393
# Client Index = 0	Epoch: 113	Loss: 0.678036
# test_correct: 0.5029; test_loss: 2.47272577047348
# Client Index = 0	Epoch: 114	Loss: 0.648127
# test_correct: 0.5008; test_loss: 2.593414659500122
# Client Index = 0	Epoch: 115	Loss: 0.661828
# test_correct: 0.5075; test_loss: 2.3415262484550476
# Client Index = 0	Epoch: 116	Loss: 0.641613
# test_correct: 0.4766; test_loss: 2.798835370540619
# Client Index = 0	Epoch: 117	Loss: 0.626464
# test_correct: 0.5123; test_loss: 2.4103734624385833
# Client Index = 0	Epoch: 118	Loss: 0.639244
# test_correct: 0.5174; test_loss: 2.3071269941329957
# Client Index = 0	Epoch: 119	Loss: 0.600706
# test_correct: 0.4994; test_loss: 2.6016743171215055
# Client Index = 0	Epoch: 120	Loss: 0.634728
# test_correct: 0.4862; test_loss: 2.629694632291794
# Client Index = 0	Epoch: 121	Loss: 0.644154
# test_correct: 0.5036; test_loss: 2.418340072631836
# Client Index = 0	Epoch: 122	Loss: 0.663455
# test_correct: 0.528; test_loss: 2.3790911340713503
# Client Index = 0	Epoch: 123	Loss: 0.597586
# test_correct: 0.491; test_loss: 2.7121122097969055
# Client Index = 0	Epoch: 124	Loss: 0.613084
# test_correct: 0.4725; test_loss: 2.791207158565521
# Client Index = 0	Epoch: 125	Loss: 0.602015
# test_correct: 0.4927; test_loss: 2.581361290216446
# Client Index = 0	Epoch: 126	Loss: 0.581173
# test_correct: 0.4977; test_loss: 2.623678722381592
# Client Index = 0	Epoch: 127	Loss: 0.581735
# test_correct: 0.534; test_loss: 2.3462618935108184
# Client Index = 0	Epoch: 128	Loss: 0.615105
# test_correct: 0.5355; test_loss: 2.2764166510105133
# Client Index = 0	Epoch: 129	Loss: 0.616290
# test_correct: 0.5209; test_loss: 3.0051069116592406
# Client Index = 0	Epoch: 130	Loss: 0.588049
# test_correct: 0.5042; test_loss: 2.4235079169273375
# Client Index = 0	Epoch: 131	Loss: 0.612982
# test_correct: 0.4879; test_loss: 2.671564189195633
# Client Index = 0	Epoch: 132	Loss: 0.589345
# test_correct: 0.4796; test_loss: 2.6633942449092864
# Client Index = 0	Epoch: 133	Loss: 0.591997
# test_correct: 0.5135; test_loss: 2.80301412820816
# Client Index = 0	Epoch: 134	Loss: 0.589995
# test_correct: 0.5124; test_loss: 2.480799927711487
# Client Index = 0	Epoch: 135	Loss: 0.571636
# test_correct: 0.5032; test_loss: 2.616719390153885
# Client Index = 0	Epoch: 136	Loss: 0.574690
# test_correct: 0.4919; test_loss: 2.781958882808685
# Client Index = 0	Epoch: 137	Loss: 0.590899
# test_correct: 0.4975; test_loss: 2.6717224740982055
# Client Index = 0	Epoch: 138	Loss: 0.536015
# test_correct: 0.4975; test_loss: 2.9328961515426637
# Client Index = 0	Epoch: 139	Loss: 0.546899
# test_correct: 0.5367; test_loss: 2.4944571220874785
# Client Index = 0	Epoch: 140	Loss: 0.565291
# test_correct: 0.4843; test_loss: 2.646614969968796
# Client Index = 0	Epoch: 141	Loss: 0.543964
# test_correct: 0.5247; test_loss: 2.4540678000450136
# Client Index = 0	Epoch: 142	Loss: 0.560244
# test_correct: 0.5001; test_loss: 2.749336522817612
# Client Index = 0	Epoch: 143	Loss: 0.519686
# test_correct: 0.5084; test_loss: 2.701230870485306
# Client Index = 0	Epoch: 144	Loss: 0.507584
# test_correct: 0.5021; test_loss: 2.6728056979179384
# Client Index = 0	Epoch: 145	Loss: 0.574301
# test_correct: 0.4951; test_loss: 2.6202453911304473
# Client Index = 0	Epoch: 146	Loss: 0.566360
# test_correct: 0.5134; test_loss: 2.67696102142334
# Client Index = 0	Epoch: 147	Loss: 0.530807
# test_correct: 0.512; test_loss: 2.517496155500412
# Client Index = 0	Epoch: 148	Loss: 0.539244
# test_correct: 0.5025; test_loss: 2.7430053114891053
# Client Index = 0	Epoch: 149	Loss: 0.522797
# test_correct: 0.5194; test_loss: 2.5784153890609742
# Client Index = 0	Epoch: 150	Loss: 0.506217
# test_correct: 0.5002; test_loss: 2.6106618463993074
# Client Index = 0	Epoch: 151	Loss: 0.564049
# test_correct: 0.5231; test_loss: 2.5119001448154448
# Client Index = 0	Epoch: 152	Loss: 0.500711
# test_correct: 0.5065; test_loss: 2.7956894969940187
# Client Index = 0	Epoch: 153	Loss: 0.496794
# test_correct: 0.5224; test_loss: 2.5559654879570006
# Client Index = 0	Epoch: 154	Loss: 0.497630
# test_correct: 0.5171; test_loss: 2.646663810014725
# Client Index = 0	Epoch: 155	Loss: 0.509252
# test_correct: 0.4933; test_loss: 2.650520783662796
# Client Index = 0	Epoch: 156	Loss: 0.485239
# test_correct: 0.5031; test_loss: 2.5995463907718657
# Client Index = 0	Epoch: 157	Loss: 0.485083
# test_correct: 0.5178; test_loss: 2.7906155025959016
# Client Index = 0	Epoch: 158	Loss: 0.485110
# test_correct: 0.5139; test_loss: 2.6680096888542177
# Client Index = 0	Epoch: 159	Loss: 0.486244
# test_correct: 0.5515; test_loss: 2.427442101240158
# Client Index = 0	Epoch: 160	Loss: 0.473909
# test_correct: 0.5038; test_loss: 2.867616209983826
# Client Index = 0	Epoch: 161	Loss: 0.511333
# test_correct: 0.5061; test_loss: 2.8038464546203614
# Client Index = 0	Epoch: 162	Loss: 0.471697
# test_correct: 0.4992; test_loss: 2.5597749161720276
# Client Index = 0	Epoch: 163	Loss: 0.446754
# test_correct: 0.5127; test_loss: 2.6052059066295623
# Client Index = 0	Epoch: 164	Loss: 0.491813
# test_correct: 0.5033; test_loss: 2.7006825649738313
# Client Index = 0	Epoch: 165	Loss: 0.456980
# test_correct: 0.527; test_loss: 2.7184751427173612
# Client Index = 0	Epoch: 166	Loss: 0.498640
# test_correct: 0.5091; test_loss: 2.766037492752075
# Client Index = 0	Epoch: 167	Loss: 0.480270
# test_correct: 0.5013; test_loss: 2.8121922147274017
# Client Index = 0	Epoch: 168	Loss: 0.477482
# test_correct: 0.5024; test_loss: 3.0007830238342286
# Client Index = 0	Epoch: 169	Loss: 0.460881
# test_correct: 0.4727; test_loss: 3.0611977410316467
# Client Index = 0	Epoch: 170	Loss: 0.477606
# test_correct: 0.52; test_loss: 2.688424768447876
# Client Index = 0	Epoch: 171	Loss: 0.440037
# test_correct: 0.4855; test_loss: 2.9109196639060975
# Client Index = 0	Epoch: 172	Loss: 0.446933
# test_correct: 0.4871; test_loss: 2.8803454732894895
# Client Index = 0	Epoch: 173	Loss: 0.467662
# test_correct: 0.5136; test_loss: 2.5836734890937807
# Client Index = 0	Epoch: 174	Loss: 0.461338
# test_correct: 0.5133; test_loss: 2.764901647567749
# Client Index = 0	Epoch: 175	Loss: 0.443976
# test_correct: 0.4905; test_loss: 2.9223019099235534
# Client Index = 0	Epoch: 176	Loss: 0.449592
# test_correct: 0.5111; test_loss: 2.7548304414749145
# Client Index = 0	Epoch: 177	Loss: 0.424599
# test_correct: 0.5177; test_loss: 2.73687819480896
# Client Index = 0	Epoch: 178	Loss: 0.472830
# test_correct: 0.5225; test_loss: 2.645486979484558
# Client Index = 0	Epoch: 179	Loss: 0.441203
# test_correct: 0.4687; test_loss: 2.924920654296875
# Client Index = 0	Epoch: 180	Loss: 0.444653
# test_correct: 0.5433; test_loss: 2.6127397096157075
# Client Index = 0	Epoch: 181	Loss: 0.431811
# test_correct: 0.5181; test_loss: 2.7214196157455444
# Client Index = 0	Epoch: 182	Loss: 0.471062
# test_correct: 0.5352; test_loss: 2.620978544950485
# Client Index = 0	Epoch: 183	Loss: 0.429782
# test_correct: 0.4922; test_loss: 2.889538571834564
# Client Index = 0	Epoch: 184	Loss: 0.418137
# test_correct: 0.4972; test_loss: 2.872146089076996
# Client Index = 0	Epoch: 185	Loss: 0.416999
# test_correct: 0.5167; test_loss: 2.6328581833839415
# Client Index = 0	Epoch: 186	Loss: 0.413041
# test_correct: 0.517; test_loss: 2.6923143541812897
# Client Index = 0	Epoch: 187	Loss: 0.424135
# test_correct: 0.5021; test_loss: 2.64707066655159
# Client Index = 0	Epoch: 188	Loss: 0.428821
# test_correct: 0.5186; test_loss: 2.74064861536026
# Client Index = 0	Epoch: 189	Loss: 0.428861
# test_correct: 0.493; test_loss: 3.139622802734375
# Client Index = 0	Epoch: 190	Loss: 0.422166
# test_correct: 0.5229; test_loss: 2.5620645558834076
# Client Index = 0	Epoch: 191	Loss: 0.397425
# test_correct: 0.4948; test_loss: 2.849938093423843
# Client Index = 0	Epoch: 192	Loss: 0.405127
# test_correct: 0.4906; test_loss: 3.100062508583069
# Client Index = 0	Epoch: 193	Loss: 0.406275
# test_correct: 0.4941; test_loss: 3.0229061818122864
# Client Index = 0	Epoch: 194	Loss: 0.413928
# test_correct: 0.5074; test_loss: 2.7445521354675293
# Client Index = 0	Epoch: 195	Loss: 0.373148
# test_correct: 0.4752; test_loss: 3.1289348125457765
# Client Index = 0	Epoch: 196	Loss: 0.399521
# test_correct: 0.5235; test_loss: 2.7704669427871704
# Client Index = 0	Epoch: 197	Loss: 0.415979
# test_correct: 0.5115; test_loss: 2.9186847400665283
# Client Index = 0	Epoch: 198	Loss: 0.396135
# test_correct: 0.4651; test_loss: 3.1825413799285887
# Client Index = 0	Epoch: 199	Loss: 0.409457
# test_correct: 0.4873; test_loss: 2.894571044445038
