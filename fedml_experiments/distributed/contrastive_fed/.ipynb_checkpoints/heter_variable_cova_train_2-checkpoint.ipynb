# %%
import sys, os
import argparse

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "./../../../../")))
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "./../../../")))

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "")))

# %%
from fedml_api.data_preprocessing.cifar10.data_loader import load_partition_data_cifar10
from fedml_api.standalone.fedavg.my_model_trainer_classification import MyModelTrainer as MyModelTrainerCLS
from fedml_api.model.contrastive_cv.resnet_with_embedding import Resnet56
from CovaMNet2 import CovaMResnet56

import torch
from torch import nn
from collections import OrderedDict
import torch.nn.functional as F

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import numpy as np
import random
import pickle
import wandb

from pcgrad import PCGrad

# from triplet_loss import TripletLoss
from hard_triplet_loss import TripletLoss
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: greenlet.greenlet size changed, may indicate binary incompatibility. Expected 144 from C header, got 152 from PyObject
# <frozen importlib._bootstrap>:219: RuntimeWarning: greenlet.greenlet size changed, may indicate binary incompatibility. Expected 144 from C header, got 152 from PyObject
# <frozen importlib._bootstrap>:219: RuntimeWarning: greenlet.greenlet size changed, may indicate binary incompatibility. Expected 144 from C header, got 152 from PyObject
# <frozen importlib._bootstrap>:219: RuntimeWarning: greenlet.greenlet size changed, may indicate binary incompatibility. Expected 144 from C header, got 152 from PyObject

# %%
dataset = 'cifar10'
data_dir = "./../../../data/cifar10"
partition_method = 'hetero'
# partition_method = 'homo'
partition_alpha = 0.5
client_num_in_total = 10
batch_size = 100
total_epochs = 500

save_model_path = 'model/cs_{0}_{1}_client_{2}_variable_covaM_epochs_{3}.pt'

device = 'cuda:2'
with_cova = True

wandb.init(
            # project="federated_nas",
            project="cova",
            name="Cova_" + str(partition_method) + "_clients" + str(client_num_in_total) + "_pcgrad_wn_adam-leaky_relu_with_cova" + str(
                with_cova)
        )
# config = wandb.config
# config.learning_rate = 0.01

with open(f'dataset_{partition_method}_{client_num_in_total}.pickle', 'rb') as f:
    dataset = pickle.load(f)
# [train_data_num, test_data_num, train_data_global, test_data_global, \
# #             train_data_local_num_dict, train_data_local_dict, test_data_local_dict, \
# #             class_num]
# Out:
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: slimfun (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.11.2<br/>
#                 Syncing run <strong style="color:#cdcd00">Cova_hetero_clients10_pcgrad_wn_adam-leaky_relu_with_covaTrue</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/slimfun/cova" target="_blank">https://wandb.ai/slimfun/cova</a><br/>
#                 Run page: <a href="https://wandb.ai/slimfun/cova/runs/3o7002j4" target="_blank">https://wandb.ai/slimfun/cova/runs/3o7002j4</a><br/>
#                 Run data is saved locally in <code>/home/fw1/nfs_mnt/FedML/fedml_experiments/distributed/contrastive_fed/wandb/run-20211112_124122-3o7002j4</code><br/><br/>

# %%
# from collections import Counter
# ls = np.array([int(l) for l in labels])
# counter_result = Counter(ls)
# print(Counter(ls))
# print(dataset[5])

# %%
# model = Resnet56(class_num=dataset[-1], neck='bnneck')
# model.load_state_dict(torch.load('model/cs_3_homo_client_0_oral_epochs_200.pt'))

# %%
with open(f'data_dict.pickle', 'rb') as f:
    data_dict = pickle.load(f)

# %%
cl = []
for k, v in data_dict.items():
#     print(len(v))
    cl.append(torch.stack(v).to(device))
# print(cl[0].shape)
print(len(cl))
# Out:
# 10

# %%
# def cal_covariance(input):

# #     CovaMatrix_list = []
# #     mean_list = []
#     B, C, h, w = input.size()
# #     print(B)
#     support_set_sam = input.permute(1, 0, 2, 3)
#     support_set_sam = support_set_sam.contiguous().view(C, -1)
    
#     mean_support = torch.mean(support_set_sam, 1, True)
# #     mean_list.append(mean_support)
    
#     support_set_sam = support_set_sam-mean_support
    
#     covariance_matrix = support_set_sam@torch.transpose(support_set_sam, 0, 1)
#     covariance_matrix = torch.div(covariance_matrix, h*w*B-1)
    
#     return covariance_matrix.clone().detach(), mean_support.clone().detach()


# def get_cova(model, device):
#     cova_list = [0 for i in range(10)]
#     mean_list = [0 for i in range(10)]
    
#     model.to(device)
#     model.eval()
    
#     features = []
    
#     with torch.no_grad():
#         for k, v in data_dict.items():
#             x = torch.stack(data_dict[k]).to(device)
# #             print(x.shape)
#             score, feats = model(x)
#             covariance_matrix, mean_support = cal_covariance(feats.to(device))
#             cova_list[k] = covariance_matrix.to(device)
#             mean_list[k] = mean_support.to(device)
            
#     return cova_list, mean_list

# %%
class Client(object):
    def __init__(self, client_index, train_data_local_dict, train_data_local_num_dict, test_data_local_dict, device, model):
        self.id = client_index
        self.train_data = train_data_local_dict[self.id]
        self.local_sample_number = train_data_local_num_dict[self.id]
        self.test_local = test_data_local_dict[self.id]
        
        self.device = device
        self.model = model
model1 = CovaMResnet56(class_num=dataset[-1], neck='bnneck', with_cova=with_cova)
client_1 = Client(0, dataset[5], dataset[4], dataset[6], device, model1)

# %%
def test(model, test_data, device, cl, ml):
#     cl = cms[0]
#     ml = cms[1]
    
    model.to(device)
    model.eval()

    metrics = {
        'test_correct': 0,
        'test_loss': 0,
        'test_total': 0,
        'correct_cova': 0
    }

    criterion = nn.CrossEntropyLoss().to(device)

    with torch.no_grad():
        for batch_idx, (x, target) in enumerate(test_data):
            x = x.to(device)
            target = target.to(device)
#             support_ml = []
#             for l in target:
#                 support_ml.append(ml[l.data].to(device))
            pred, pred_ce_cova, feat = model(x, cl, ml=None)
            loss = criterion(pred, target)
            
#             loss_ce_cova = criterion(pred_ce_cova, target)

            _, predicted = torch.max(pred, -1)
            _, predicted_ce_cova = torch.max(pred_ce_cova, -1)
            correct = predicted.eq(target).sum()
            correct_ce_cova = predicted_ce_cova.eq(target).sum()

            metrics['test_correct'] += correct.item()
#             metrics['test_correct'] += correct_ce_cova.item()
            metrics['test_loss'] += loss.item() * target.size(0)
            metrics['test_total'] += target.size(0)
            metrics['correct_cova'] += correct_ce_cova.item()
            
    return metrics

def train_model(client, epochs):
#     learning_rate = 0.001
#     wd = 0.0001
#     learning_rate = 0.00035
#     wd = 0.0005

#     cl = cms[0]
#     ml = cms[1]
    
    
    margin = 0.3
    
    client.model.to(client.device)
    client.model.train()
    
    criterion = nn.CrossEntropyLoss().to(device)
    criterion2 = nn.CrossEntropyLoss().to(device)
    mse_loss = nn.MSELoss().to(device)
    
#     curr_lr = learning_rate
#     optimizer = torch.optim.Adam(filter(lambda p: p.requires_grad, client.model.parameters()), lr=curr_lr,
#                                          weight_decay=wd, amsgrad=True)
#     optimizer = torch.optim.SGD(client.model.parameters(), lr=0.001,
#                       momentum=0.9, weight_decay=5e-4)
    optimizer = PCGrad(torch.optim.Adam(client.model.parameters(), lr=0.001, betas=(0.5, 0.9)))
#     scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)

    epoch_loss = []
    total_step = len(client.train_data)
#     wandb.watch(client.model, log='all')
    lbd = 0.1
    for epoch in range(epochs):
        
#         if epoch > 0:
        
#         print(ml[0])
        
        client.model.train()
        batch_loss = []
        for batch_idx, (x, labels) in enumerate(client.train_data):
            
#             cl, ml = get_cova(client.model, client.device)
#             if epoch > 0:
#                 print(cl[0])
            x, labels = x.to(device), labels.to(device)
#             print(labels.shape)
            client.model.zero_grad()
#             support_ml = []
#             for l in labels:
#                 # B, 256, 64
#                 support_ml.append(ml[l.data].to(device))
#             print(cl[0].shape)
            cls_score, cova_score, feat = client.model(x, support_imgs=cl, ml=None)
#             print(score.shape)
#             print(cova_score)
#             print(cova_score)
#             loss = criterion(cova_score, labels).to(device)
#             if epoch < 100:
#             loss = criterion(cls_score, labels)
#             if epoch > 100 :
#             loss = criterion(cova_score, labels).to(device)
#             loss = loss.to(device) + criterion(cova_score, labels).to(device)
            loss1 = criterion(cls_score, labels)
            loss2 = criterion2(cova_score, labels)
            losses = [loss1, loss2]
    
            lbd += (1-0.1) / (epochs-100)
#             loss.backward()
            optimizer.pc_backward(losses)
        
#             torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

            optimizer.step()
            batch_loss.append((loss1+loss2).item())
        
#         print(cl[0])
            
#         if epoch % 50 == 0:
#             torch.save(client.model.state_dict(), str.format(save_model_path, client_num_in_total, partition_method, client.id, epoch))
        epoch_loss.append(sum(batch_loss) / len(batch_loss))
#         scheduler.step()
        print('Client Index = {}\tEpoch: {}\tLoss: {:.6f}'.format(
            client.id, epoch, sum(batch_loss) / len(batch_loss)))
        
        metrics = test(client.model, client.test_local, client.device, cl, None)
        test_correct = metrics['test_correct']/metrics['test_total']
        test_loss = metrics['test_loss']/metrics['test_total']
        correct_ce_cova = metrics['correct_cova']/metrics['test_total']
#         print(metrics['test_total'])
        print(f'test_correct: {test_correct}; test_loss: {test_loss}')
        wandb.log({
#             'epoch' : epoch,
            'train_loss': sum(batch_loss) / len(batch_loss),
            'test_correct' : test_correct,
            'test_loss' : test_loss,
            'correct_cova' : correct_ce_cova
        }, step=epoch)
        
    torch.save(client.model.state_dict(), str.format(save_model_path, client_num_in_total, partition_method, client.id, epochs))

# %%
train_model(client_1, 200)
# Out:
# Client Index = 0	Epoch: 0	Loss: 11.384620
# test_correct: 0.2246; test_loss: 2.2665313959121702
# Client Index = 0	Epoch: 1	Loss: 4.442470
# test_correct: 0.2923; test_loss: 2.2289145040512084
# Client Index = 0	Epoch: 5	Loss: 2.952702
# test_correct: 0.3157; test_loss: 2.3577374947071075
# Client Index = 0	Epoch: 6	Loss: 2.869323
# test_correct: 0.3104; test_loss: 2.173287045955658
# Client Index = 0	Epoch: 7	Loss: 2.779943
# test_correct: 0.3045; test_loss: 2.3717627704143522
# Client Index = 0	Epoch: 8	Loss: 2.716294
# test_correct: 0.3327; test_loss: 2.1180858707427976
# Client Index = 0	Epoch: 9	Loss: 2.608388
# test_correct: 0.3168; test_loss: 2.220892360210419
# Client Index = 0	Epoch: 10	Loss: 2.549417
# test_correct: 0.3526; test_loss: 2.1031314194202424
# Client Index = 0	Epoch: 11	Loss: 2.484450
# test_correct: 0.3392; test_loss: 2.1813187623023986
# Client Index = 0	Epoch: 12	Loss: 2.469537
# test_correct: 0.3537; test_loss: 2.0777996587753296
# Client Index = 0	Epoch: 13	Loss: 2.417475
# test_correct: 0.3489; test_loss: 2.054345197677612
# Client Index = 0	Epoch: 14	Loss: 2.343279
# test_correct: 0.3382; test_loss: 2.1347460389137267
# Client Index = 0	Epoch: 15	Loss: 2.327891
# test_correct: 0.3423; test_loss: 2.038273434638977
# Client Index = 0	Epoch: 16	Loss: 2.284207
# test_correct: 0.3679; test_loss: 2.050866229534149
# Client Index = 0	Epoch: 17	Loss: 2.202300
# test_correct: 0.3719; test_loss: 2.00573912858963
# Client Index = 0	Epoch: 18	Loss: 2.186196
# test_correct: 0.3783; test_loss: 2.070120689868927
# Client Index = 0	Epoch: 19	Loss: 2.145672
# test_correct: 0.3742; test_loss: 2.1214025950431825
# Client Index = 0	Epoch: 20	Loss: 2.116814
# test_correct: 0.4119; test_loss: 1.9744838190078735
# Client Index = 0	Epoch: 21	Loss: 2.033957
# test_correct: 0.372; test_loss: 2.097395043373108
# Client Index = 0	Epoch: 22	Loss: 2.008221
# test_correct: 0.3824; test_loss: 2.0479579067230222
# Client Index = 0	Epoch: 23	Loss: 1.975702
# test_correct: 0.419; test_loss: 1.8551393091678618
# Client Index = 0	Epoch: 24	Loss: 1.955783
# test_correct: 0.3969; test_loss: 2.0119371497631073
# Client Index = 0	Epoch: 25	Loss: 1.915457
# test_correct: 0.3808; test_loss: 1.9806112921237946
# Client Index = 0	Epoch: 26	Loss: 1.883863
# test_correct: 0.4173; test_loss: 1.927264449596405
# Client Index = 0	Epoch: 27	Loss: 1.829618
# test_correct: 0.4161; test_loss: 2.0530362248420717
# Client Index = 0	Epoch: 28	Loss: 1.813314
# test_correct: 0.3866; test_loss: 2.025193907022476
# Client Index = 0	Epoch: 29	Loss: 1.819452
# test_correct: 0.4174; test_loss: 1.8748761785030366
# Client Index = 0	Epoch: 30	Loss: 1.747791
# test_correct: 0.4157; test_loss: 2.03090344786644
# Client Index = 0	Epoch: 31	Loss: 1.716958
# test_correct: 0.4369; test_loss: 1.97483682513237
# Client Index = 0	Epoch: 32	Loss: 1.740246
# test_correct: 0.3858; test_loss: 2.0757359313964843
# Client Index = 0	Epoch: 33	Loss: 1.717923
# test_correct: 0.3814; test_loss: 2.2889127910137175
# Client Index = 0	Epoch: 34	Loss: 1.705209
# test_correct: 0.4352; test_loss: 1.9400080513954163
# Client Index = 0	Epoch: 35	Loss: 1.643476
# test_correct: 0.4197; test_loss: 2.065586233139038
# Client Index = 0	Epoch: 36	Loss: 1.652047
# test_correct: 0.4419; test_loss: 2.0400586676597596
# Client Index = 0	Epoch: 37	Loss: 1.584945
# test_correct: 0.3987; test_loss: 2.1505673575401305
# Client Index = 0	Epoch: 38	Loss: 1.592824
# test_correct: 0.4209; test_loss: 2.131891219615936
# Client Index = 0	Epoch: 39	Loss: 1.564923
# test_correct: 0.4195; test_loss: 2.1182340812683105
# Client Index = 0	Epoch: 40	Loss: 1.556232
# test_correct: 0.434; test_loss: 2.104746462106705
# Client Index = 0	Epoch: 41	Loss: 1.503070
# test_correct: 0.4078; test_loss: 2.26956969499588
# Client Index = 0	Epoch: 42	Loss: 1.497230
# test_correct: 0.406; test_loss: 2.2015950095653536
# Client Index = 0	Epoch: 43	Loss: 1.516406
# test_correct: 0.4017; test_loss: 2.279637408256531
# Client Index = 0	Epoch: 44	Loss: 1.450764
# test_correct: 0.4405; test_loss: 2.137726603746414
# Client Index = 0	Epoch: 45	Loss: 1.485202
# test_correct: 0.4252; test_loss: 2.2075957798957826
# Client Index = 0	Epoch: 46	Loss: 1.415606
# test_correct: 0.4214; test_loss: 2.228247332572937
# Client Index = 0	Epoch: 47	Loss: 1.397963
# test_correct: 0.4529; test_loss: 2.2415057468414306
# Client Index = 0	Epoch: 48	Loss: 1.400861
# test_correct: 0.4461; test_loss: 2.299886519908905
# Client Index = 0	Epoch: 49	Loss: 1.381578
# test_correct: 0.4453; test_loss: 2.2116600251197815
# Client Index = 0	Epoch: 50	Loss: 1.342791
# test_correct: 0.4172; test_loss: 2.3115782153606417
# Client Index = 0	Epoch: 51	Loss: 1.370152
# test_correct: 0.4088; test_loss: 2.3232094860076904
# Client Index = 0	Epoch: 52	Loss: 1.315170
# test_correct: 0.4635; test_loss: 2.1437819361686707
# Client Index = 0	Epoch: 53	Loss: 1.305239
# test_correct: 0.4374; test_loss: 2.248875423669815
# Client Index = 0	Epoch: 54	Loss: 1.284001
# test_correct: 0.4479; test_loss: 2.1772041547298433
# Client Index = 0	Epoch: 55	Loss: 1.271064
# test_correct: 0.427; test_loss: 2.278432492017746
# Client Index = 0	Epoch: 56	Loss: 1.281145
# test_correct: 0.4622; test_loss: 2.0390336310863493
# Client Index = 0	Epoch: 57	Loss: 1.308316
# test_correct: 0.4423; test_loss: 2.218305826187134
# Client Index = 0	Epoch: 58	Loss: 1.250446
# test_correct: 0.4214; test_loss: 2.310148470401764
# Client Index = 0	Epoch: 62	Loss: 1.208388
# test_correct: 0.4427; test_loss: 2.244910453557968
# Client Index = 0	Epoch: 63	Loss: 1.181861
# test_correct: 0.4319; test_loss: 2.300279641151428
# Client Index = 0	Epoch: 64	Loss: 1.171894
# test_correct: 0.4271; test_loss: 2.310133798122406
# Client Index = 0	Epoch: 65	Loss: 1.150843
# test_correct: 0.4202; test_loss: 2.2941633248329163
# Client Index = 0	Epoch: 66	Loss: 1.158082
# test_correct: 0.4294; test_loss: 2.3743492555618286
# Client Index = 0	Epoch: 67	Loss: 1.183479
# test_correct: 0.4704; test_loss: 2.072232012748718
# Client Index = 0	Epoch: 68	Loss: 1.113519
# test_correct: 0.4479; test_loss: 2.262751181125641
# Client Index = 0	Epoch: 69	Loss: 1.081110
# test_correct: 0.4235; test_loss: 2.3428651547431945
# Client Index = 0	Epoch: 70	Loss: 1.089220
# test_correct: 0.4582; test_loss: 2.26047327041626
# Client Index = 0	Epoch: 71	Loss: 1.050021
# test_correct: 0.4511; test_loss: 2.2686814355850218
# Client Index = 0	Epoch: 72	Loss: 1.057282
# test_correct: 0.47; test_loss: 2.2555923891067504
# Client Index = 0	Epoch: 73	Loss: 1.040663
# test_correct: 0.4413; test_loss: 2.223012800216675
# Client Index = 0	Epoch: 74	Loss: 1.063856
# test_correct: 0.4819; test_loss: 2.1435223984718323
# Client Index = 0	Epoch: 75	Loss: 1.055368
# test_correct: 0.4546; test_loss: 2.266097128391266
# test_correct: 0.437; test_loss: 2.3664118337631224
# Client Index = 0	Epoch: 79	Loss: 1.013566
# test_correct: 0.4367; test_loss: 2.41724280834198
# Client Index = 0	Epoch: 80	Loss: 1.026013
# test_correct: 0.3846; test_loss: 2.514079451560974
# Client Index = 0	Epoch: 81	Loss: 1.000981
# test_correct: 0.4624; test_loss: 2.414239706993103
# Client Index = 0	Epoch: 82	Loss: 0.995131
# test_correct: 0.4487; test_loss: 2.3523790085315706
# Client Index = 0	Epoch: 83	Loss: 0.989934
# test_correct: 0.4211; test_loss: 2.4218918967247007
# Client Index = 0	Epoch: 84	Loss: 0.947968
# test_correct: 0.4396; test_loss: 2.4180996692180634
# Client Index = 0	Epoch: 85	Loss: 0.965121
# test_correct: 0.4418; test_loss: 2.2915569400787352
# Client Index = 0	Epoch: 86	Loss: 0.948172
# test_correct: 0.4175; test_loss: 2.443069189786911
# Client Index = 0	Epoch: 87	Loss: 0.908824
# test_correct: 0.4373; test_loss: 2.4335161912441254
# Client Index = 0	Epoch: 88	Loss: 0.927059
# test_correct: 0.4293; test_loss: 2.5194408965110777
# Client Index = 0	Epoch: 89	Loss: 0.900611
# test_correct: 0.4207; test_loss: 2.5167222213745117
# Client Index = 0	Epoch: 90	Loss: 0.941266
# test_correct: 0.4415; test_loss: 2.3745934545993803
# Client Index = 0	Epoch: 91	Loss: 0.906838
# test_correct: 0.454; test_loss: 2.34178178191185
# Client Index = 0	Epoch: 92	Loss: 0.902414
# test_correct: 0.4151; test_loss: 2.501228665113449
# Client Index = 0	Epoch: 93	Loss: 0.866515
# test_correct: 0.3906; test_loss: 2.708977324962616
# Client Index = 0	Epoch: 94	Loss: 0.896901
# test_correct: 0.4402; test_loss: 2.4404149758815765
# Client Index = 0	Epoch: 95	Loss: 0.876038
# test_correct: 0.4104; test_loss: 2.4601594543457033
# Client Index = 0	Epoch: 96	Loss: 0.894802
# test_correct: 0.4437; test_loss: 2.38599413394928
# Client Index = 0	Epoch: 97	Loss: 0.866979
# test_correct: 0.4274; test_loss: 2.3805988574028016
# Client Index = 0	Epoch: 98	Loss: 0.841310
# test_correct: 0.4467; test_loss: 2.3835983335971833
# Client Index = 0	Epoch: 99	Loss: 0.836180
# test_correct: 0.4496; test_loss: 2.322027349472046
# Client Index = 0	Epoch: 100	Loss: 0.853048
# test_correct: 0.4404; test_loss: 2.3420889842510224
# Client Index = 0	Epoch: 101	Loss: 0.808019
# test_correct: 0.4472; test_loss: 2.353388622999191
# Client Index = 0	Epoch: 102	Loss: 0.805999
# test_correct: 0.463; test_loss: 2.2977981102466583
# Client Index = 0	Epoch: 103	Loss: 0.794217
# test_correct: 0.4374; test_loss: 2.483380492925644
# Client Index = 0	Epoch: 104	Loss: 0.831863
# test_correct: 0.4367; test_loss: 2.5277407145500184
# Client Index = 0	Epoch: 105	Loss: 0.801616
# test_correct: 0.4412; test_loss: 2.436967066526413
# Client Index = 0	Epoch: 106	Loss: 0.812118
# test_correct: 0.4549; test_loss: 2.5089579856395723
# Client Index = 0	Epoch: 107	Loss: 0.813159
# test_correct: 0.4627; test_loss: 2.396868393421173
# Client Index = 0	Epoch: 108	Loss: 0.789007
# test_correct: 0.441; test_loss: 2.4867367219924925
# Client Index = 0	Epoch: 109	Loss: 0.783539
# test_correct: 0.4852; test_loss: 2.3092966520786287
# Client Index = 0	Epoch: 110	Loss: 0.754867
# test_correct: 0.461; test_loss: 2.377695302963257
# Client Index = 0	Epoch: 111	Loss: 0.783993
# test_correct: 0.4537; test_loss: 2.4501355290412903
# Client Index = 0	Epoch: 112	Loss: 0.793202
# test_correct: 0.4345; test_loss: 2.5731493973731996
# Client Index = 0	Epoch: 113	Loss: 0.756298
# test_correct: 0.4606; test_loss: 2.5217390859127047
# Client Index = 0	Epoch: 114	Loss: 0.771041
# test_correct: 0.4346; test_loss: 2.5499798893928527
# Client Index = 0	Epoch: 115	Loss: 0.736641
# test_correct: 0.4559; test_loss: 2.439653025865555
# Client Index = 0	Epoch: 116	Loss: 0.749857
# test_correct: 0.4639; test_loss: 2.4549361753463743
# Client Index = 0	Epoch: 117	Loss: 0.740896
# test_correct: 0.4488; test_loss: 2.4333648705482482
# Client Index = 0	Epoch: 118	Loss: 0.785702
# test_correct: 0.4521; test_loss: 2.4914257669448854
# Client Index = 0	Epoch: 119	Loss: 0.724077
# test_correct: 0.4439; test_loss: 2.5282955265045164
# Client Index = 0	Epoch: 120	Loss: 0.713267
# test_correct: 0.437; test_loss: 2.5051448225975035
# Client Index = 0	Epoch: 121	Loss: 0.724668
# test_correct: 0.4806; test_loss: 2.455473666191101
# Client Index = 0	Epoch: 122	Loss: 0.726775
# test_correct: 0.4711; test_loss: 2.497492825984955
# Client Index = 0	Epoch: 123	Loss: 0.710945
# test_correct: 0.5066; test_loss: 2.2923964846134184
# Client Index = 0	Epoch: 124	Loss: 0.700327
# test_correct: 0.454; test_loss: 2.415936863422394
# Client Index = 0	Epoch: 125	Loss: 0.690593
# test_correct: 0.4484; test_loss: 2.5890182757377627
# Client Index = 0	Epoch: 126	Loss: 0.684469
# test_correct: 0.4839; test_loss: 2.4950032806396485
# Client Index = 0	Epoch: 127	Loss: 0.683904
# test_correct: 0.4609; test_loss: 2.4245676040649413
# Client Index = 0	Epoch: 128	Loss: 0.672109
# test_correct: 0.4732; test_loss: 2.5234921097755434
# Client Index = 0	Epoch: 129	Loss: 0.720092
# test_correct: 0.4492; test_loss: 2.505941690206528
# Client Index = 0	Epoch: 130	Loss: 0.689063
# test_correct: 0.4673; test_loss: 2.4914772629737856
# Client Index = 0	Epoch: 131	Loss: 0.647001
# Client Index = 0	Epoch: 132	Loss: 0.654566
# test_correct: 0.4865; test_loss: 2.490160335302353
# Client Index = 0	Epoch: 133	Loss: 0.675175
# test_correct: 0.4455; test_loss: 2.515445593595505
# Client Index = 0	Epoch: 134	Loss: 0.651563
# test_correct: 0.4683; test_loss: 2.576882404088974
# Client Index = 0	Epoch: 135	Loss: 0.655583
# test_correct: 0.449; test_loss: 2.5947518718242644
# Client Index = 0	Epoch: 136	Loss: 0.628373
# test_correct: 0.4461; test_loss: 2.6255978143215177
# Client Index = 0	Epoch: 137	Loss: 0.672870
# test_correct: 0.4679; test_loss: 2.5823036766052248
# Client Index = 0	Epoch: 138	Loss: 0.606578
# test_correct: 0.4735; test_loss: 2.5534645223617556
# Client Index = 0	Epoch: 139	Loss: 0.651308
# test_correct: 0.4426; test_loss: 2.6276852321624755
# Client Index = 0	Epoch: 140	Loss: 0.621509
# test_correct: 0.4977; test_loss: 2.393141436576843
# Client Index = 0	Epoch: 141	Loss: 0.599167
# test_correct: 0.5018; test_loss: 2.412143943309784
# Client Index = 0	Epoch: 142	Loss: 0.611246
# test_correct: 0.4783; test_loss: 2.55184143781662
# Client Index = 0	Epoch: 143	Loss: 0.621319
# test_correct: 0.4589; test_loss: 2.6805350160598755
# Client Index = 0	Epoch: 144	Loss: 0.598873
# test_correct: 0.4447; test_loss: 2.727248120307922
# Client Index = 0	Epoch: 145	Loss: 0.614554
# test_correct: 0.4329; test_loss: 2.725061674118042
# Client Index = 0	Epoch: 146	Loss: 0.638404
# test_correct: 0.4816; test_loss: 2.4970361685752867
# Client Index = 0	Epoch: 147	Loss: 0.580153
# test_correct: 0.4869; test_loss: 2.5721862745285033
# Client Index = 0	Epoch: 148	Loss: 0.602316
# test_correct: 0.4952; test_loss: 2.5085008478164674
# Client Index = 0	Epoch: 149	Loss: 0.612042
# test_correct: 0.4773; test_loss: 2.5738087737560273
# Client Index = 0	Epoch: 150	Loss: 0.592661
# test_correct: 0.5043; test_loss: 2.374785989522934
# Client Index = 0	Epoch: 151	Loss: 0.614410
# test_correct: 0.4998; test_loss: 2.4593666779994963
# Client Index = 0	Epoch: 152	Loss: 0.593631
# test_correct: 0.4213; test_loss: 2.8073067224025725
# Client Index = 0	Epoch: 153	Loss: 0.614647
# test_correct: 0.4904; test_loss: 2.4461374640464784
# Client Index = 0	Epoch: 154	Loss: 0.600452
# test_correct: 0.461; test_loss: 2.5102131462097166
# Client Index = 0	Epoch: 155	Loss: 0.567245
# test_correct: 0.484; test_loss: 2.54248046875
# Client Index = 0	Epoch: 156	Loss: 0.565277
# test_correct: 0.465; test_loss: 2.650278285741806
# Client Index = 0	Epoch: 157	Loss: 0.589738
# test_correct: 0.4814; test_loss: 2.5373980808258056
# Client Index = 0	Epoch: 158	Loss: 0.551983
# test_correct: 0.4689; test_loss: 2.5481556463241577
# Client Index = 0	Epoch: 159	Loss: 0.571459
# test_correct: 0.4867; test_loss: 2.5699581694602966
# Client Index = 0	Epoch: 160	Loss: 0.553221
# test_correct: 0.4581; test_loss: 2.6594716584682465
# Client Index = 0	Epoch: 161	Loss: 0.549778
# test_correct: 0.4955; test_loss: 2.5508517980575562
# Client Index = 0	Epoch: 162	Loss: 0.534592
# test_correct: 0.4687; test_loss: 2.6006128931045533
# Client Index = 0	Epoch: 163	Loss: 0.544562
# test_correct: 0.5045; test_loss: 2.458161875009537
# Client Index = 0	Epoch: 164	Loss: 0.570730
# test_correct: 0.5007; test_loss: 2.4693132710456847
# Client Index = 0	Epoch: 165	Loss: 0.545646
# test_correct: 0.5074; test_loss: 2.4823532581329344
# Client Index = 0	Epoch: 166	Loss: 0.524854
# test_correct: 0.4909; test_loss: 2.57260315656662
# Client Index = 0	Epoch: 167	Loss: 0.541325
# test_correct: 0.4863; test_loss: 2.522437945604324
# Client Index = 0	Epoch: 168	Loss: 0.502977
# test_correct: 0.4716; test_loss: 2.624878213405609
# Client Index = 0	Epoch: 169	Loss: 0.500597
# test_correct: 0.4835; test_loss: 2.5662516915798186
# Client Index = 0	Epoch: 170	Loss: 0.512969
# test_correct: 0.4874; test_loss: 2.581396378278732
# Client Index = 0	Epoch: 171	Loss: 0.529886
# test_correct: 0.4857; test_loss: 2.552021868228912
# Client Index = 0	Epoch: 172	Loss: 0.513946
# test_correct: 0.4614; test_loss: 2.6657598328590395
# Client Index = 0	Epoch: 173	Loss: 0.501222
# test_correct: 0.4888; test_loss: 2.545895644426346
# Client Index = 0	Epoch: 174	Loss: 0.528323
# test_correct: 0.5319; test_loss: 2.407078881263733
# Client Index = 0	Epoch: 175	Loss: 0.505883
# test_correct: 0.4949; test_loss: 2.571169682741165
# Client Index = 0	Epoch: 176	Loss: 0.522062
# test_correct: 0.4735; test_loss: 2.7232240724563597
# Client Index = 0	Epoch: 177	Loss: 0.506329
# test_correct: 0.4825; test_loss: 2.7122751700878145
# Client Index = 0	Epoch: 178	Loss: 0.496499
# test_correct: 0.4683; test_loss: 2.686277321577072
# Client Index = 0	Epoch: 179	Loss: 0.518206
# test_correct: 0.4684; test_loss: 2.6711807918548582
# Client Index = 0	Epoch: 180	Loss: 0.481004
# test_correct: 0.4731; test_loss: 2.6203271305561064
# Client Index = 0	Epoch: 181	Loss: 0.507318
# test_correct: 0.467; test_loss: 2.778135038614273
# Client Index = 0	Epoch: 182	Loss: 0.487725
# test_correct: 0.4711; test_loss: 2.5955582952499388
# Client Index = 0	Epoch: 183	Loss: 0.514419
# test_correct: 0.446; test_loss: 2.7544601488113405
# Client Index = 0	Epoch: 184	Loss: 0.486678
# test_correct: 0.4524; test_loss: 2.701686050891876
# Client Index = 0	Epoch: 185	Loss: 0.491043
# test_correct: 0.5076; test_loss: 2.5777773678302767
# Client Index = 0	Epoch: 186	Loss: 0.482402
# test_correct: 0.4805; test_loss: 2.6922225511074065
# Client Index = 0	Epoch: 187	Loss: 0.460527
# test_correct: 0.4495; test_loss: 2.787053506374359
# Client Index = 0	Epoch: 188	Loss: 0.479513
# test_correct: 0.4802; test_loss: 2.675731683969498
# Client Index = 0	Epoch: 189	Loss: 0.496687
# test_correct: 0.5012; test_loss: 2.575315474271774
# Client Index = 0	Epoch: 190	Loss: 0.448473
# test_correct: 0.4799; test_loss: 2.66014723777771
# Client Index = 0	Epoch: 191	Loss: 0.470678
# test_correct: 0.4602; test_loss: 2.7882383608818055
# Client Index = 0	Epoch: 192	Loss: 0.460752
# test_correct: 0.4707; test_loss: 2.8021980476379396
# Client Index = 0	Epoch: 193	Loss: 0.456991
# test_correct: 0.477; test_loss: 2.7005279624462126
# Client Index = 0	Epoch: 194	Loss: 0.462403
# test_correct: 0.4825; test_loss: 2.7671246910095215
# Client Index = 0	Epoch: 195	Loss: 0.454109
# test_correct: 0.4839; test_loss: 2.732701621055603
# Client Index = 0	Epoch: 196	Loss: 0.462516
# test_correct: 0.4726; test_loss: 2.816654710769653
# Client Index = 0	Epoch: 197	Loss: 0.474430
# test_correct: 0.457; test_loss: 2.861227333545685
# Client Index = 0	Epoch: 198	Loss: 0.436786
# test_correct: 0.4922; test_loss: 2.7385575413703918
# Client Index = 0	Epoch: 199	Loss: 0.463506
# test_correct: 0.4891; test_loss: 2.666371101140976
